# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.optimizers import Adam
from math import sqrt
import matplotlib.pyplot as plt

df = pd.read_csv('B_train.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

X_data = df.to_numpy()
y_data = df['PM25_Concentration'].to_numpy()

def get_processed_data(X_data, y_data, sequence_length, ste p_size):
    X_train = []
    y_train = []

    for i in range(0, X_data.shape[0] - sequence_length - step_size):
        X_train.append(X_data[i: i + sequence_length])
        y_train.append(y_data[i + sequence_length: i + sequence_length + step_size].tolist())

    X_train = np.array(X_train)
    y_train = np.array(y_train)
    return X_train, y_train

def train_lstm_model(X_train, y_train, epochs=100, batch_size=72):
    model = Sequential()
    model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))

    model.add(Dense(y_train.shape[1]))
    model.compile(loss='mse',  optimizer='adam')
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=2, shuffle=False)

    return model, history

df_test = pd.read_csv('B_test.csv')
df_test.drop('Unnamed: 0', axis=1, inplace=True)

X_test = df_test.to_numpy()
y_test = df_test['PM25_Concentration'].to_numpy()

def get_processed_test_data(X_test, y_test, sequence_length, step_size):
    X_test_processed = []
    y_test_processed = []

    for i in range(0, X_test.shape[0] - sequence_length - step_size):
        X_test_processed.append(X_test[i : i + sequence_length])
        y_test_processed.append(y_test[i + sequence_length: i + sequence_length + step_size].tolist())

    X_test_processed = np.array(X_test_processed)
    y_test_processed = np.array(y_test_processed)

    return X_test_processed, y_test_processed


step_sizes = [1, 7, 14, 30, 60]
sequence_len = [5,18,30,70,120]

for k in range(len(step_sizes)):
    step_size, sequencelen=step_sizes[k],sequence_len[k]
    X_train, y_train = get_processed_data(X_data, y_data, sequencelen, step_size)
    model, history = train_lstm_model(X_train, y_train)

    X_test_processed, y_test_processed = get_processed_test_data(X_test, y_test, sequencelen, step_size)
    y_pred = model.predict(X_test_processed)

    print(y_pred)
    print(y_test_processed)

    mse = mean_squared_error(y_test_processed, y_pred)
    print(f"Mean Squared Error (MSE) for step size {step_size}: {mse}")
    mae = mean_absolute_error(y_test_processed, y_pred)
    print(f"Mean Absolute Error (MAE) for step size {step_size}: {mae}")
    y_test_values = [val[0] for val in y_test_processed]
    y_pred_values = [val[0] for val in y_pred]

    plt.figure(figsize=(20, 5))
    plt.plot(y_test_values, label=f'Actual (Step Size {step_size})', alpha=0.6)
    plt.plot(y_pred_values, label=f'Predicted (Step Size {step_size})', alpha=0.6)

    plt.title(f'Actual vs Predicted PM25 Concentration on Test Data (Step Size {step_size})')
    plt.xlabel('Time Step')
    plt.ylabel('Normalized PM25 Concentration')
    plt.legend()
    plt.show()
# Out:
# Epoch 1/100
# 98/98 - 3s - loss: 13726.2373 - 3s/epoch - 30ms/step
# Epoch 2/100
# 98/98 - 0s - loss: 11952.3652 - 483ms/epoch - 5ms/step
# Epoch 3/100
# 98/98 - 0s - loss: 10915.4834 - 456ms/epoch - 5ms/step
# Epoch 4/100
# 98/98 - 0s - loss: 10083.1836 - 347ms/epoch - 4ms/step
# Epoch 5/100
# 98/98 - 0s - loss: 9380.5771 - 330ms/epoch - 3ms/step
# Epoch 6/100
# 98/98 - 0s - loss: 8774.1943 - 353ms/epoch - 4ms/step
# Epoch 7/100
# 98/98 - 0s - loss: 8237.7041 - 351ms/epoch - 4ms/step
# Epoch 8/100
# 98/98 - 0s - loss: 7758.0854 - 331ms/epoch - 3ms/step
# Epoch 9/100
# 98/98 - 0s - loss: 7326.0532 - 352ms/epoch - 4ms/step
# Epoch 10/100
# 98/98 - 0s - loss: 6934.9692 - 354ms/epoch - 4ms/step
# Epoch 11/100
# 98/98 - 0s - loss: 6578.9961 - 328ms/epoch - 3ms/step
# Epoch 12/100
# 98/98 - 0s - loss: 6253.6831 - 344ms/epoch - 4ms/step
# Epoch 13/100
# 98/98 - 0s - loss: 5954.6982 - 368ms/epoch - 4ms/step
# Epoch 14/100
# 98/98 - 0s - loss: 5668.6997 - 343ms/epoch - 3ms/step
# Epoch 15/100
# 98/98 - 0s - loss: 5402.8154 - 350ms/epoch - 4ms/step
# Epoch 16/100
# 98/98 - 0s - loss: 5160.7290 - 340ms/epoch - 3ms/step
# Epoch 17/100
# 98/98 - 0s - loss: 4936.7568 - 313ms/epoch - 3ms/step
# Epoch 18/100
# 98/98 - 0s - loss: 4728.3110 - 338ms/epoch - 3ms/step
# Epoch 19/100
# 98/98 - 0s - loss: 4533.4409 - 335ms/epoch - 3ms/step
# Epoch 20/100
# 98/98 - 0s - loss: 4350.5215 - 316ms/epoch - 3ms/step
# Epoch 21/100
# 98/98 - 0s - loss: 4179.0269 - 334ms/epoch - 3ms/step
# Epoch 22/100
# 98/98 - 0s - loss: 4015.7505 - 350ms/epoch - 4ms/step
# Epoch 23/100
# 98/98 - 0s - loss: 3862.4688 - 338ms/epoch - 3ms/step
# Epoch 24/100
# 98/98 - 0s - loss: 3717.6726 - 347ms/epoch - 4ms/step
# Epoch 25/100
# 98/98 - 0s - loss: 3580.6052 - 328ms/epoch - 3ms/step
# Epoch 26/100
# 98/98 - 0s - loss: 3450.6465 - 346ms/epoch - 4ms/step
# Epoch 27/100
# 98/98 - 0s - loss: 3326.9246 - 345ms/epoch - 4ms/step
# Epoch 28/100
# 98/98 - 0s - loss: 3208.6047 - 341ms/epoch - 3ms/step
# Epoch 29/100
# 98/98 - 0s - loss: 3096.3567 - 339ms/epoch - 3ms/step
# Epoch 30/100
# 98/98 - 0s - loss: 2988.7495 - 338ms/epoch - 3ms/step
# Epoch 31/100
# 98/98 - 0s - loss: 2886.1799 - 331ms/epoch - 3ms/step
# Epoch 32/100
# 98/98 - 0s - loss: 2787.9399 - 355ms/epoch - 4ms/step
# Epoch 33/100
# 98/98 - 0s - loss: 2701.9961 - 497ms/epoch - 5ms/step
# Epoch 34/100
# 98/98 - 0s - loss: 2604.4548 - 469ms/epoch - 5ms/step
# Epoch 35/100
# 98/98 - 0s - loss: 2518.3655 - 479ms/epoch - 5ms/step
# Epoch 36/100
# 98/98 - 0s - loss: 2436.4780 - 477ms/epoch - 5ms/step
# Epoch 37/100
# 98/98 - 0s - loss: 2357.6956 - 481ms/epoch - 5ms/step
# Epoch 38/100
# 98/98 - 0s - loss: 2293.1799 - 463ms/epoch - 5ms/step
# Epoch 39/100
# 98/98 - 0s - loss: 2210.2869 - 471ms/epoch - 5ms/step
# Epoch 40/100
# 98/98 - 0s - loss: 2140.9500 - 463ms/epoch - 5ms/step
# Epoch 41/100
# 98/98 - 1s - loss: 2162.3809 - 588ms/epoch - 6ms/step
# Epoch 42/100
# 98/98 - 1s - loss: 2102.9734 - 512ms/epoch - 5ms/step
# Epoch 43/100
# 98/98 - 1s - loss: 2071.1587 - 621ms/epoch - 6ms/step
# Epoch 44/100
# 98/98 - 1s - loss: 2048.6455 - 520ms/epoch - 5ms/step
# Epoch 45/100
# 98/98 - 0s - loss: 1982.4780 - 348ms/epoch - 4ms/step
# Epoch 46/100
# 98/98 - 0s - loss: 1892.0983 - 349ms/epoch - 4ms/step
# Epoch 47/100
# 98/98 - 0s - loss: 1917.6930 - 351ms/epoch - 4ms/step
# Epoch 48/100
# 98/98 - 0s - loss: 1881.2324 - 331ms/epoch - 3ms/step
# Epoch 49/100
# 98/98 - 0s - loss: 1813.2655 - 351ms/epoch - 4ms/step
# Epoch 50/100
# 98/98 - 0s - loss: 1760.0944 - 361ms/epoch - 4ms/step
# Epoch 51/100
# 98/98 - 0s - loss: 1750.8740 - 334ms/epoch - 3ms/step
# Epoch 52/100
# 98/98 - 0s - loss: 1703.1653 - 329ms/epoch - 3ms/step
# Epoch 53/100
# 98/98 - 0s - loss: 1653.6299 - 325ms/epoch - 3ms/step
# Epoch 54/100
# 98/98 - 0s - loss: 1606.4465 - 332ms/epoch - 3ms/step
# Epoch 55/100
# 98/98 - 0s - loss: 1562.0648 - 342ms/epoch - 3ms/step
# Epoch 56/100
# 98/98 - 0s - loss: 1520.1837 - 349ms/epoch - 4ms/step
# Epoch 57/100
# 98/98 - 0s - loss: 1477.6742 - 325ms/epoch - 3ms/step
# Epoch 58/100
# 98/98 - 0s - loss: 1505.2250 - 332ms/epoch - 3ms/step
# Epoch 59/100
# 98/98 - 0s - loss: 1438.3477 - 347ms/epoch - 4ms/step
# Epoch 60/100
# 98/98 - 0s - loss: 1465.3026 - 325ms/epoch - 3ms/step
# Epoch 61/100
# 98/98 - 0s - loss: 1425.5743 - 344ms/epoch - 4ms/step
# Epoch 62/100
# 98/98 - 0s - loss: 1386.6021 - 339ms/epoch - 3ms/step
# Epoch 63/100
# 98/98 - 0s - loss: 1348.6213 - 324ms/epoch - 3ms/step
# Epoch 64/100
# 98/98 - 0s - loss: 1312.9252 - 351ms/epoch - 4ms/step
# Epoch 65/100
# 98/98 - 0s - loss: 1276.5551 - 335ms/epoch - 3ms/step
# Epoch 66/100
# 98/98 - 0s - loss: 1243.8440 - 335ms/epoch - 3ms/step
# Epoch 67/100
# 98/98 - 0s - loss: 1211.4392 - 433ms/epoch - 4ms/step
# Epoch 68/100
# 98/98 - 0s - loss: 1184.4124 - 486ms/epoch - 5ms/step
# Epoch 69/100
# 98/98 - 0s - loss: 1152.9362 - 479ms/epoch - 5ms/step
# Epoch 70/100
# 98/98 - 0s - loss: 1123.3300 - 455ms/epoch - 5ms/step
# Epoch 71/100
# 98/98 - 0s - loss: 1094.3087 - 476ms/epoch - 5ms/step
# Epoch 72/100
# 98/98 - 0s - loss: 1066.9818 - 443ms/epoch - 5ms/step
# Epoch 73/100
# 98/98 - 0s - loss: 1047.6589 - 437ms/epoch - 4ms/step
# Epoch 74/100
# 98/98 - 1s - loss: 1016.3174 - 503ms/epoch - 5ms/step
# Epoch 75/100
# 98/98 - 0s - loss: 993.9579 - 373ms/epoch - 4ms/step
# Epoch 76/100
# 98/98 - 0s - loss: 968.4493 - 353ms/epoch - 4ms/step
# Epoch 77/100
# 98/98 - 0s - loss: 946.3112 - 330ms/epoch - 3ms/step
# Epoch 78/100
# 98/98 - 0s - loss: 923.7704 - 312ms/epoch - 3ms/step
# Epoch 79/100
# 98/98 - 0s - loss: 903.0179 - 338ms/epoch - 3ms/step
# Epoch 80/100
# 98/98 - 0s - loss: 882.3844 - 349ms/epoch - 4ms/step
# Epoch 81/100
# 98/98 - 0s - loss: 862.6248 - 324ms/epoch - 3ms/step
# Epoch 82/100
# 98/98 - 0s - loss: 844.3710 - 354ms/epoch - 4ms/step
# Epoch 83/100
# 98/98 - 0s - loss: 824.7946 - 339ms/epoch - 3ms/step
# Epoch 84/100
# 98/98 - 0s - loss: 806.5921 - 336ms/epoch - 3ms/step
# Epoch 85/100
# 98/98 - 0s - loss: 796.5029 - 356ms/epoch - 4ms/step
# Epoch 86/100
# 98/98 - 0s - loss: 778.9226 - 323ms/epoch - 3ms/step
# Epoch 87/100
# 98/98 - 0s - loss: 761.4353 - 343ms/epoch - 3ms/step
# Epoch 88/100
# 98/98 - 0s - loss: 745.2601 - 339ms/epoch - 3ms/step
# Epoch 89/100
# 98/98 - 0s - loss: 734.6268 - 336ms/epoch - 3ms/step
# Epoch 90/100
# 98/98 - 0s - loss: 718.0079 - 331ms/epoch - 3ms/step
# Epoch 91/100
# 98/98 - 0s - loss: 705.1345 - 354ms/epoch - 4ms/step
# Epoch 92/100
# 98/98 - 0s - loss: 688.8514 - 343ms/epoch - 3ms/step
# Epoch 93/100
# 98/98 - 0s - loss: 673.9302 - 352ms/epoch - 4ms/step
# Epoch 94/100
# 98/98 - 0s - loss: 662.5837 - 369ms/epoch - 4ms/step
# Epoch 95/100
# 98/98 - 0s - loss: 649.6055 - 342ms/epoch - 3ms/step
# Epoch 96/100
# 98/98 - 0s - loss: 636.9353 - 346ms/epoch - 4ms/step
# Epoch 97/100
# 98/98 - 0s - loss: 626.7758 - 349ms/epoch - 4ms/step
# Epoch 98/100
# 98/98 - 0s - loss: 614.3326 - 337ms/epoch - 3ms/step
# Epoch 99/100
# 98/98 - 0s - loss: 602.0432 - 346ms/epoch - 4ms/step
# Epoch 100/100
# 98/98 - 0s - loss: 590.9130 - 361ms/epoch - 4ms/step
# 54/54 [==============================] - 1s 3ms/step
# [[ 19.73809 ]
#  [ 15.826786]
#  [ 15.440857]
#  ...
#  [114.000946]
#  [117.11423 ]
#  [125.31607 ]]
# [[ 16.]
#  [ 13.]
#  [ 14.]
#  ...
#  [117.]
#  [119.]
#  [109.]]
# Mean Squared Error (MSE) for step size 1: 552.9032437287292
# Mean Absolute Error (MAE) for step size 1: 12.786478626126131
# Epoch 1/100
# 97/97 - 2s - loss: 14196.9482 - 2s/epoch - 22ms/step
# Epoch 2/100
# 97/97 - 0s - loss: 12380.7344 - 382ms/epoch - 4ms/step
# Epoch 3/100
# 97/97 - 0s - loss: 11266.4795 - 386ms/epoch - 4ms/step
# Epoch 4/100
# 97/97 - 0s - loss: 10402.7373 - 354ms/epoch - 4ms/step
# Epoch 5/100
# 97/97 - 0s - loss: 9681.3115 - 388ms/epoch - 4ms/step
# Epoch 6/100
# 97/97 - 0s - loss: 9066.0537 - 387ms/epoch - 4ms/step
# Epoch 7/100
# 97/97 - 0s - loss: 8529.3232 - 370ms/epoch - 4ms/step
# Epoch 8/100
# 97/97 - 0s - loss: 8058.5181 - 374ms/epoch - 4ms/step
# Epoch 9/100
# 97/97 - 0s - loss: 7641.4424 - 374ms/epoch - 4ms/step
# Epoch 10/100
# 97/97 - 0s - loss: 7271.0391 - 406ms/epoch - 4ms/step
# Epoch 11/100
# 97/97 - 0s - loss: 6939.8613 - 390ms/epoch - 4ms/step
# Epoch 12/100
# 97/97 - 0s - loss: 6641.8608 - 359ms/epoch - 4ms/step
# Epoch 13/100
# 97/97 - 0s - loss: 6372.4077 - 368ms/epoch - 4ms/step
# Epoch 14/100
# 97/97 - 0s - loss: 6129.6997 - 387ms/epoch - 4ms/step
# Epoch 15/100
# 97/97 - 0s - loss: 5890.2808 - 361ms/epoch - 4ms/step
# Epoch 16/100
# 97/97 - 0s - loss: 5755.9375 - 366ms/epoch - 4ms/step
# Epoch 17/100
# 97/97 - 0s - loss: 5535.5562 - 361ms/epoch - 4ms/step
# Epoch 18/100
# 97/97 - 0s - loss: 5355.8125 - 376ms/epoch - 4ms/step
# Epoch 19/100
# 97/97 - 0s - loss: 5187.9526 - 366ms/epoch - 4ms/step
# Epoch 20/100
# 97/97 - 0s - loss: 5035.1201 - 370ms/epoch - 4ms/step
# Epoch 21/100
# 97/97 - 0s - loss: 4891.4775 - 441ms/epoch - 5ms/step
# Epoch 22/100
# 97/97 - 0s - loss: 4758.8784 - 490ms/epoch - 5ms/step
# Epoch 23/100
# 97/97 - 1s - loss: 4694.0405 - 528ms/epoch - 5ms/step
# Epoch 24/100
# 97/97 - 1s - loss: 4718.8047 - 501ms/epoch - 5ms/step
# Epoch 25/100
# 97/97 - 1s - loss: 4569.4268 - 510ms/epoch - 5ms/step
# Epoch 26/100
# 97/97 - 0s - loss: 4462.7358 - 494ms/epoch - 5ms/step
# Epoch 27/100
# 97/97 - 1s - loss: 4349.1055 - 507ms/epoch - 5ms/step
# Epoch 28/100
# 97/97 - 1s - loss: 4253.2524 - 527ms/epoch - 5ms/step
# Epoch 29/100
# 97/97 - 0s - loss: 4115.6074 - 409ms/epoch - 4ms/step
# Epoch 30/100
# 97/97 - 0s - loss: 3997.4194 - 375ms/epoch - 4ms/step
# Epoch 31/100
# 97/97 - 0s - loss: 3866.0105 - 367ms/epoch - 4ms/step
# Epoch 32/100
# 97/97 - 0s - loss: 3929.5361 - 379ms/epoch - 4ms/step
# Epoch 33/100
# 97/97 - 0s - loss: 3825.9468 - 372ms/epoch - 4ms/step
# Epoch 34/100
# 97/97 - 0s - loss: 3751.1917 - 374ms/epoch - 4ms/step
# Epoch 35/100
# 97/97 - 0s - loss: 3727.4578 - 369ms/epoch - 4ms/step
# Epoch 36/100
# 97/97 - 0s - loss: 3645.7185 - 387ms/epoch - 4ms/step
# Epoch 37/100
# 97/97 - 0s - loss: 3628.6328 - 361ms/epoch - 4ms/step
# Epoch 38/100
# 97/97 - 0s - loss: 3551.3721 - 365ms/epoch - 4ms/step
# Epoch 39/100
# 97/97 - 0s - loss: 3482.0781 - 362ms/epoch - 4ms/step
# Epoch 40/100
# 97/97 - 0s - loss: 3512.9883 - 367ms/epoch - 4ms/step
# Epoch 41/100
# 97/97 - 0s - loss: 3378.0710 - 360ms/epoch - 4ms/step
# Epoch 42/100
# 97/97 - 0s - loss: 3316.4202 - 383ms/epoch - 4ms/step
# Epoch 43/100
# 97/97 - 0s - loss: 3387.2815 - 359ms/epoch - 4ms/step
# Epoch 44/100
# 97/97 - 0s - loss: 3294.0945 - 386ms/epoch - 4ms/step
# Epoch 45/100
# 97/97 - 0s - loss: 3224.1653 - 358ms/epoch - 4ms/step
# Epoch 46/100
# 97/97 - 0s - loss: 3173.3665 - 379ms/epoch - 4ms/step
# Epoch 47/100
# 97/97 - 0s - loss: 3159.0112 - 367ms/epoch - 4ms/step
# Epoch 48/100
# 97/97 - 0s - loss: 3127.5056 - 369ms/epoch - 4ms/step
# Epoch 49/100
# 97/97 - 0s - loss: 3075.6169 - 391ms/epoch - 4ms/step
# Epoch 50/100
# 97/97 - 0s - loss: 3097.3354 - 396ms/epoch - 4ms/step
# Epoch 51/100
# 97/97 - 0s - loss: 2984.5613 - 360ms/epoch - 4ms/step
# Epoch 52/100
# 97/97 - 0s - loss: 2938.8049 - 392ms/epoch - 4ms/step
# Epoch 53/100
# 97/97 - 0s - loss: 2898.3577 - 392ms/epoch - 4ms/step
# Epoch 54/100
# 97/97 - 0s - loss: 2863.3118 - 391ms/epoch - 4ms/step
# Epoch 55/100
# 97/97 - 1s - loss: 2860.3586 - 506ms/epoch - 5ms/step
# Epoch 56/100
# 97/97 - 1s - loss: 2764.8691 - 500ms/epoch - 5ms/step
# Epoch 57/100
# 97/97 - 1s - loss: 2739.0061 - 533ms/epoch - 5ms/step
# Epoch 58/100
# 97/97 - 0s - loss: 2714.3713 - 471ms/epoch - 5ms/step
# Epoch 59/100
# 97/97 - 1s - loss: 2704.3508 - 542ms/epoch - 6ms/step
# Epoch 60/100
# 97/97 - 0s - loss: 2648.7771 - 493ms/epoch - 5ms/step
# Epoch 61/100
# 97/97 - 1s - loss: 2620.1228 - 502ms/epoch - 5ms/step
# Epoch 62/100
# 97/97 - 0s - loss: 2591.2581 - 457ms/epoch - 5ms/step
# Epoch 63/100
# 97/97 - 0s - loss: 2594.9324 - 392ms/epoch - 4ms/step
# Epoch 64/100
# 97/97 - 0s - loss: 2569.7581 - 357ms/epoch - 4ms/step
# Epoch 65/100
# 97/97 - 0s - loss: 2517.7188 - 382ms/epoch - 4ms/step
# Epoch 66/100
# 97/97 - 0s - loss: 2500.0515 - 373ms/epoch - 4ms/step
# Epoch 67/100
# 97/97 - 0s - loss: 2475.7073 - 353ms/epoch - 4ms/step
# Epoch 68/100
# 97/97 - 0s - loss: 2456.1516 - 395ms/epoch - 4ms/step
# Epoch 69/100
# 97/97 - 0s - loss: 2438.2122 - 350ms/epoch - 4ms/step
# Epoch 70/100
# 97/97 - 0s - loss: 2406.0833 - 368ms/epoch - 4ms/step
# Epoch 71/100
# 97/97 - 0s - loss: 2391.0889 - 388ms/epoch - 4ms/step
# Epoch 72/100
# 97/97 - 0s - loss: 2363.0544 - 347ms/epoch - 4ms/step
# Epoch 73/100
# 97/97 - 0s - loss: 2350.8535 - 349ms/epoch - 4ms/step
# Epoch 74/100
# 97/97 - 0s - loss: 2380.9724 - 364ms/epoch - 4ms/step
# Epoch 75/100
# 97/97 - 0s - loss: 2358.8577 - 347ms/epoch - 4ms/step
# Epoch 76/100
# 97/97 - 0s - loss: 2351.1523 - 387ms/epoch - 4ms/step
# Epoch 77/100
# 97/97 - 0s - loss: 2307.4038 - 350ms/epoch - 4ms/step
# Epoch 78/100
# 97/97 - 0s - loss: 2276.3540 - 354ms/epoch - 4ms/step
# Epoch 79/100
# 97/97 - 0s - loss: 2248.8960 - 386ms/epoch - 4ms/step
# Epoch 80/100
# 97/97 - 0s - loss: 2233.9548 - 350ms/epoch - 4ms/step
# Epoch 81/100
# 97/97 - 0s - loss: 2224.4316 - 337ms/epoch - 3ms/step
# Epoch 82/100
# 97/97 - 0s - loss: 2201.8057 - 362ms/epoch - 4ms/step
# Epoch 83/100
# 97/97 - 0s - loss: 2191.0359 - 367ms/epoch - 4ms/step
# Epoch 84/100
# 97/97 - 0s - loss: 2170.8027 - 375ms/epoch - 4ms/step
# Epoch 85/100
# 97/97 - 0s - loss: 2159.8242 - 387ms/epoch - 4ms/step
# Epoch 86/100
# 97/97 - 0s - loss: 2161.3169 - 380ms/epoch - 4ms/step
# Epoch 87/100
# 97/97 - 0s - loss: 2160.7490 - 373ms/epoch - 4ms/step
# Epoch 88/100
# 97/97 - 0s - loss: 2170.7124 - 356ms/epoch - 4ms/step
# Epoch 89/100
# 97/97 - 0s - loss: 2179.9390 - 432ms/epoch - 4ms/step
# Epoch 90/100
# 97/97 - 0s - loss: 2150.6104 - 492ms/epoch - 5ms/step
# Epoch 91/100
# 97/97 - 1s - loss: 2137.5823 - 503ms/epoch - 5ms/step
# Epoch 92/100
# 97/97 - 0s - loss: 2165.4792 - 490ms/epoch - 5ms/step
# Epoch 93/100
# 97/97 - 1s - loss: 2116.7690 - 524ms/epoch - 5ms/step
# Epoch 94/100
# 97/97 - 0s - loss: 2103.6853 - 495ms/epoch - 5ms/step
# Epoch 95/100
# 97/97 - 0s - loss: 2091.1436 - 495ms/epoch - 5ms/step
# Epoch 96/100
# 97/97 - 0s - loss: 2070.5085 - 482ms/epoch - 5ms/step
# Epoch 97/100
# 97/97 - 0s - loss: 2061.8989 - 412ms/epoch - 4ms/step
# Epoch 98/100
# 97/97 - 0s - loss: 2049.9246 - 484ms/epoch - 5ms/step
# Epoch 99/100
# 97/97 - 0s - loss: 2053.9287 - 369ms/epoch - 4ms/step
# Epoch 100/100
# 97/97 - 0s - loss: 2037.3495 - 372ms/epoch - 4ms/step
# 54/54 [==============================] - 0s 2ms/step
# [[ 16.581108  16.714163  19.200222 ...  22.914888  25.883913  27.42336 ]
#  [ 13.565785  13.444544  15.816622 ...  19.44493   22.090923  23.776049]
#  [ 15.779932  15.573901  17.701057 ...  20.952234  23.767048  25.137104]
#  ...
#  [106.767426 106.6697   106.86201  ... 107.35726  107.411026 106.28055 ]
#  [101.58314  102.07344  102.415085 ... 103.57559  103.627426 102.79316 ]
#  [123.36618  123.6316   123.95678  ... 123.88316  122.85339  121.60325 ]]
# [[ 17.  17.  17. ...  17.  17.  17.]
#  [ 17.  17.  17. ...  17.  17.  17.]
#  [ 17.  17.  17. ...  17.  17.  17.]
#  ...
#  [111. 117. 117. ... 110. 117. 117.]
#  [117. 117. 111. ... 117. 117. 119.]
#  [117. 111. 110. ... 117. 119. 109.]]
# Mean Squared Error (MSE) for step size 7: 2155.6706463459354
# Mean Absolute Error (MAE) for step size 7: 29.216660433811764
# Epoch 1/100
# 97/97 - 2s - loss: 14364.9912 - 2s/epoch - 22ms/step
# Epoch 2/100
# 97/97 - 0s - loss: 12648.0664 - 391ms/epoch - 4ms/step
# Epoch 3/100
# 97/97 - 0s - loss: 11462.4873 - 386ms/epoch - 4ms/step
# Epoch 4/100
# 97/97 - 0s - loss: 10607.3750 - 392ms/epoch - 4ms/step
# Epoch 5/100
# 97/97 - 0s - loss: 9913.6299 - 408ms/epoch - 4ms/step
# Epoch 6/100
# 97/97 - 0s - loss: 9317.1982 - 396ms/epoch - 4ms/step
# Epoch 7/100
# 97/97 - 0s - loss: 8799.4316 - 415ms/epoch - 4ms/step
# Epoch 8/100
# 97/97 - 0s - loss: 8355.2432 - 379ms/epoch - 4ms/step
# Epoch 9/100
# 97/97 - 0s - loss: 7969.8369 - 382ms/epoch - 4ms/step
# Epoch 10/100
# 97/97 - 0s - loss: 7636.7832 - 408ms/epoch - 4ms/step
# Epoch 11/100
# 97/97 - 0s - loss: 7330.4971 - 401ms/epoch - 4ms/step
# Epoch 12/100
# 97/97 - 0s - loss: 7064.0786 - 423ms/epoch - 4ms/step
# Epoch 13/100
# 97/97 - 0s - loss: 6827.4805 - 380ms/epoch - 4ms/step
# Epoch 14/100
# 97/97 - 1s - loss: 6615.2407 - 566ms/epoch - 6ms/step
# Epoch 15/100
# 97/97 - 1s - loss: 6425.3701 - 563ms/epoch - 6ms/step
# Epoch 16/100
# 97/97 - 1s - loss: 6314.5967 - 561ms/epoch - 6ms/step
# Epoch 17/100
# 97/97 - 1s - loss: 6158.9385 - 548ms/epoch - 6ms/step
# Epoch 18/100
# 97/97 - 1s - loss: 6007.2808 - 558ms/epoch - 6ms/step
# Epoch 19/100
# 97/97 - 1s - loss: 5864.4336 - 528ms/epoch - 5ms/step
# Epoch 20/100
# 97/97 - 1s - loss: 5716.2285 - 555ms/epoch - 6ms/step
# Epoch 21/100
# 97/97 - 0s - loss: 5598.8433 - 401ms/epoch - 4ms/step
# Epoch 22/100
# 97/97 - 0s - loss: 5625.4702 - 396ms/epoch - 4ms/step
# Epoch 23/100
# 97/97 - 0s - loss: 5521.4497 - 388ms/epoch - 4ms/step
# Epoch 24/100
# 97/97 - 0s - loss: 5464.8340 - 423ms/epoch - 4ms/step
# Epoch 25/100
# 97/97 - 0s - loss: 5324.4106 - 413ms/epoch - 4ms/step
# Epoch 26/100
# 97/97 - 0s - loss: 5268.9546 - 399ms/epoch - 4ms/step
# Epoch 27/100
# 97/97 - 0s - loss: 5195.8413 - 404ms/epoch - 4ms/step
# Epoch 28/100
# 97/97 - 0s - loss: 5072.9512 - 393ms/epoch - 4ms/step
# Epoch 29/100
# 97/97 - 0s - loss: 4944.1396 - 422ms/epoch - 4ms/step
# Epoch 30/100
# 97/97 - 0s - loss: 4879.1738 - 402ms/epoch - 4ms/step
# Epoch 31/100
# 97/97 - 0s - loss: 4814.4600 - 422ms/epoch - 4ms/step
# Epoch 32/100
# 97/97 - 0s - loss: 4750.5479 - 409ms/epoch - 4ms/step
# Epoch 33/100
# 97/97 - 0s - loss: 4680.7319 - 414ms/epoch - 4ms/step
# Epoch 34/100
# 97/97 - 0s - loss: 4623.8052 - 431ms/epoch - 4ms/step
# Epoch 35/100
# 97/97 - 0s - loss: 4636.6660 - 387ms/epoch - 4ms/step
# Epoch 36/100
# 97/97 - 0s - loss: 4648.1460 - 396ms/epoch - 4ms/step
# Epoch 37/100
# 97/97 - 0s - loss: 4579.2217 - 387ms/epoch - 4ms/step
# Epoch 38/100
# 97/97 - 0s - loss: 4511.3730 - 385ms/epoch - 4ms/step
# Epoch 39/100
# 97/97 - 0s - loss: 4457.9458 - 376ms/epoch - 4ms/step
# Epoch 40/100
# 97/97 - 0s - loss: 4405.2568 - 396ms/epoch - 4ms/step
# Epoch 41/100
# 97/97 - 0s - loss: 4389.4033 - 411ms/epoch - 4ms/step
# Epoch 42/100
# 97/97 - 0s - loss: 4364.9966 - 405ms/epoch - 4ms/step
# Epoch 43/100
# 97/97 - 0s - loss: 4306.4434 - 397ms/epoch - 4ms/step
# Epoch 44/100
# 97/97 - 0s - loss: 4263.4536 - 421ms/epoch - 4ms/step
# Epoch 45/100
# 97/97 - 1s - loss: 4223.9980 - 516ms/epoch - 5ms/step
# Epoch 46/100
# 97/97 - 1s - loss: 4248.0312 - 575ms/epoch - 6ms/step
# Epoch 47/100
# 97/97 - 1s - loss: 4201.6494 - 575ms/epoch - 6ms/step
# Epoch 48/100
# 97/97 - 1s - loss: 4224.7734 - 571ms/epoch - 6ms/step
# Epoch 49/100
# 97/97 - 1s - loss: 4171.4922 - 574ms/epoch - 6ms/step
# Epoch 50/100
# 97/97 - 1s - loss: 4138.7173 - 557ms/epoch - 6ms/step
# Epoch 51/100
# 97/97 - 1s - loss: 4117.8218 - 529ms/epoch - 5ms/step
# Epoch 52/100
# 97/97 - 0s - loss: 4041.7791 - 419ms/epoch - 4ms/step
# Epoch 53/100
# 97/97 - 0s - loss: 4004.4521 - 413ms/epoch - 4ms/step
# Epoch 54/100
# 97/97 - 0s - loss: 3979.8281 - 401ms/epoch - 4ms/step
# Epoch 55/100
# 97/97 - 0s - loss: 3973.2415 - 394ms/epoch - 4ms/step
# Epoch 56/100
# 97/97 - 0s - loss: 3945.4399 - 406ms/epoch - 4ms/step
# Epoch 57/100
# 97/97 - 0s - loss: 3932.4595 - 405ms/epoch - 4ms/step
# Epoch 58/100
# 97/97 - 0s - loss: 3887.1169 - 416ms/epoch - 4ms/step
# Epoch 59/100
# 97/97 - 0s - loss: 3882.9197 - 399ms/epoch - 4ms/step
# Epoch 60/100
# 97/97 - 0s - loss: 3836.9473 - 398ms/epoch - 4ms/step
# Epoch 61/100
# 97/97 - 0s - loss: 3812.2041 - 402ms/epoch - 4ms/step
# Epoch 62/100
# 97/97 - 0s - loss: 3783.4949 - 411ms/epoch - 4ms/step
# Epoch 63/100
# 97/97 - 0s - loss: 3788.5286 - 395ms/epoch - 4ms/step
# Epoch 64/100
# 97/97 - 0s - loss: 3740.3792 - 405ms/epoch - 4ms/step
# Epoch 65/100
# 97/97 - 0s - loss: 3744.7117 - 384ms/epoch - 4ms/step
# Epoch 66/100
# 97/97 - 0s - loss: 3745.9917 - 408ms/epoch - 4ms/step
# Epoch 67/100
# 97/97 - 0s - loss: 3736.8083 - 403ms/epoch - 4ms/step
# Epoch 68/100
# 97/97 - 0s - loss: 3688.8484 - 419ms/epoch - 4ms/step
# Epoch 69/100
# 97/97 - 0s - loss: 3676.8640 - 428ms/epoch - 4ms/step
# Epoch 70/100
# 97/97 - 0s - loss: 3717.4956 - 402ms/epoch - 4ms/step
# Epoch 71/100
# 97/97 - 0s - loss: 3693.2090 - 420ms/epoch - 4ms/step
# Epoch 72/100
# 97/97 - 0s - loss: 3636.0884 - 387ms/epoch - 4ms/step
# Epoch 73/100
# 97/97 - 0s - loss: 3619.5806 - 412ms/epoch - 4ms/step
# Epoch 74/100
# 97/97 - 0s - loss: 3602.0408 - 414ms/epoch - 4ms/step
# Epoch 75/100
# 97/97 - 0s - loss: 3623.2927 - 401ms/epoch - 4ms/step
# Epoch 76/100
# 97/97 - 0s - loss: 3609.8118 - 496ms/epoch - 5ms/step
# Epoch 77/100
# 97/97 - 1s - loss: 3591.4551 - 570ms/epoch - 6ms/step
# Epoch 78/100
# 97/97 - 1s - loss: 3555.9021 - 541ms/epoch - 6ms/step
# Epoch 79/100
# 97/97 - 1s - loss: 3546.2012 - 588ms/epoch - 6ms/step
# Epoch 80/100
# 97/97 - 1s - loss: 3534.2732 - 529ms/epoch - 5ms/step
# Epoch 81/100
# 97/97 - 1s - loss: 3538.3921 - 545ms/epoch - 6ms/step
# Epoch 82/100
# 97/97 - 1s - loss: 3538.5386 - 560ms/epoch - 6ms/step
# Epoch 83/100
# 97/97 - 0s - loss: 3528.3843 - 422ms/epoch - 4ms/step
# Epoch 84/100
# 97/97 - 0s - loss: 3499.4131 - 408ms/epoch - 4ms/step
# Epoch 85/100
# 97/97 - 0s - loss: 3479.4731 - 393ms/epoch - 4ms/step
# Epoch 86/100
# 97/97 - 0s - loss: 3470.3926 - 391ms/epoch - 4ms/step
# Epoch 87/100
# 97/97 - 0s - loss: 3469.8677 - 402ms/epoch - 4ms/step
# Epoch 88/100
# 97/97 - 0s - loss: 3439.4268 - 412ms/epoch - 4ms/step
# Epoch 89/100
# 97/97 - 0s - loss: 3442.7280 - 411ms/epoch - 4ms/step
# Epoch 90/100
# 97/97 - 0s - loss: 3414.6760 - 413ms/epoch - 4ms/step
# Epoch 91/100
# 97/97 - 0s - loss: 3384.3118 - 421ms/epoch - 4ms/step
# Epoch 92/100
# 97/97 - 0s - loss: 3386.2966 - 396ms/epoch - 4ms/step
# Epoch 93/100
# 97/97 - 0s - loss: 3375.9287 - 413ms/epoch - 4ms/step
# Epoch 94/100
# 97/97 - 0s - loss: 3406.4072 - 424ms/epoch - 4ms/step
# Epoch 95/100
# 97/97 - 0s - loss: 3389.8894 - 404ms/epoch - 4ms/step
# Epoch 96/100
# 97/97 - 0s - loss: 3359.7092 - 408ms/epoch - 4ms/step
# Epoch 97/100
# 97/97 - 0s - loss: 3332.2437 - 393ms/epoch - 4ms/step
# Epoch 98/100
# 97/97 - 0s - loss: 3304.5066 - 401ms/epoch - 4ms/step
# Epoch 99/100
# 97/97 - 0s - loss: 3290.4380 - 400ms/epoch - 4ms/step
# Epoch 100/100
# 97/97 - 0s - loss: 3286.2341 - 399ms/epoch - 4ms/step
# 53/53 [==============================] - 0s 3ms/step
# [[ 62.971386  65.48806   68.26897  ...  83.87495   84.66754   85.09121 ]
#  [ 63.148357  65.66716   68.42109  ...  83.99401   84.7767    85.18169 ]
#  [ 62.947254  65.482796  68.23962  ...  83.85628   84.65456   85.06816 ]
#  ...
#  [122.312996 122.85313  121.7509   ... 115.51857  114.865456 114.05048 ]
#  [138.6303   138.48842  137.05061  ... 125.92187  125.13191  123.96032 ]
#  [143.43956  143.01247  141.08409  ... 127.75881  126.90659  125.738625]]
# [[ 17.  17.  17. ...  17.  17.  17.]
#  [ 17.  17.  17. ...  17.  17.  17.]
#  [ 17.  17.  17. ...  17.  17.  17.]
#  ...
#  [118. 130. 139. ... 110. 117. 117.]
#  [130. 139. 154. ... 117. 117. 119.]
#  [139. 154. 161. ... 117. 119. 109.]]
# Mean Squared Error (MSE) for step size 14: 3208.862149247252
# Mean Absolute Error (MAE) for step size 14: 39.43796241949958
# Epoch 1/100
# 96/96 - 3s - loss: 14459.2051 - 3s/epoch - 36ms/step
# Epoch 2/100
# 96/96 - 1s - loss: 12847.1885 - 666ms/epoch - 7ms/step
# Epoch 3/100
# 96/96 - 1s - loss: 11728.4971 - 718ms/epoch - 7ms/step
# Epoch 4/100
# 96/96 - 1s - loss: 10874.1719 - 593ms/epoch - 6ms/step
# Epoch 5/100
# 96/96 - 0s - loss: 10175.8379 - 468ms/epoch - 5ms/step
# Epoch 6/100
# 96/96 - 0s - loss: 9621.5420 - 470ms/epoch - 5ms/step
# Epoch 7/100
# 96/96 - 0s - loss: 9177.1143 - 475ms/epoch - 5ms/step
# Epoch 8/100
# 96/96 - 1s - loss: 8801.3594 - 503ms/epoch - 5ms/step
# Epoch 9/100
# 96/96 - 0s - loss: 8460.6602 - 473ms/epoch - 5ms/step
# Epoch 10/100
# 96/96 - 0s - loss: 8166.8979 - 472ms/epoch - 5ms/step
# Epoch 11/100
# 96/96 - 1s - loss: 7910.1978 - 506ms/epoch - 5ms/step
# Epoch 12/100
# 96/96 - 0s - loss: 7693.8672 - 469ms/epoch - 5ms/step
# Epoch 13/100
# 96/96 - 0s - loss: 7502.5068 - 484ms/epoch - 5ms/step
# Epoch 14/100
# 96/96 - 0s - loss: 7335.1338 - 475ms/epoch - 5ms/step
# Epoch 15/100
# 96/96 - 1s - loss: 7186.1699 - 517ms/epoch - 5ms/step
# Epoch 16/100
# 96/96 - 0s - loss: 7054.1265 - 470ms/epoch - 5ms/step
# Epoch 17/100
# 96/96 - 0s - loss: 6935.7100 - 500ms/epoch - 5ms/step
# Epoch 18/100
# 96/96 - 0s - loss: 6829.5527 - 465ms/epoch - 5ms/step
# Epoch 19/100
# 96/96 - 1s - loss: 6734.0425 - 500ms/epoch - 5ms/step
# Epoch 20/100
# 96/96 - 0s - loss: 6646.4404 - 484ms/epoch - 5ms/step
# Epoch 21/100
# 96/96 - 0s - loss: 6565.0791 - 470ms/epoch - 5ms/step
# Epoch 22/100
# 96/96 - 0s - loss: 6490.6099 - 473ms/epoch - 5ms/step
# Epoch 23/100
# 96/96 - 0s - loss: 6422.7817 - 499ms/epoch - 5ms/step
# Epoch 24/100
# 96/96 - 0s - loss: 6362.0908 - 467ms/epoch - 5ms/step
# Epoch 25/100
# 96/96 - 1s - loss: 6303.2407 - 705ms/epoch - 7ms/step
# Epoch 26/100
# 96/96 - 1s - loss: 6298.3931 - 642ms/epoch - 7ms/step
# Epoch 27/100
# 96/96 - 1s - loss: 6231.9282 - 658ms/epoch - 7ms/step
# Epoch 28/100
# 96/96 - 1s - loss: 6177.9238 - 672ms/epoch - 7ms/step
# Epoch 29/100
# 96/96 - 1s - loss: 6127.2290 - 630ms/epoch - 7ms/step
# Epoch 30/100
# 96/96 - 1s - loss: 6077.7559 - 597ms/epoch - 6ms/step
# Epoch 31/100
# 96/96 - 0s - loss: 6038.8330 - 487ms/epoch - 5ms/step
# Epoch 32/100
# 96/96 - 0s - loss: 5994.8130 - 497ms/epoch - 5ms/step
# Epoch 33/100
# 96/96 - 0s - loss: 5953.9292 - 457ms/epoch - 5ms/step
# Epoch 34/100
# 96/96 - 0s - loss: 5909.2314 - 483ms/epoch - 5ms/step
# Epoch 35/100
# 96/96 - 0s - loss: 5870.8633 - 467ms/epoch - 5ms/step
# Epoch 36/100
# 96/96 - 0s - loss: 5862.3745 - 485ms/epoch - 5ms/step
# Epoch 37/100
# 96/96 - 0s - loss: 5890.7046 - 464ms/epoch - 5ms/step
# Epoch 38/100
# 96/96 - 0s - loss: 5879.1309 - 483ms/epoch - 5ms/step
# Epoch 39/100
# 96/96 - 0s - loss: 5831.9077 - 479ms/epoch - 5ms/step
# Epoch 40/100
# 96/96 - 0s - loss: 5791.2437 - 487ms/epoch - 5ms/step
# Epoch 41/100
# 96/96 - 0s - loss: 5752.0405 - 466ms/epoch - 5ms/step
# Epoch 42/100
# 96/96 - 1s - loss: 5698.8940 - 514ms/epoch - 5ms/step
# Epoch 43/100
# 96/96 - 0s - loss: 5667.2939 - 465ms/epoch - 5ms/step
# Epoch 44/100
# 96/96 - 1s - loss: 5677.1494 - 507ms/epoch - 5ms/step
# Epoch 45/100
# 96/96 - 0s - loss: 5640.0532 - 466ms/epoch - 5ms/step
# Epoch 46/100
# 96/96 - 1s - loss: 5580.4595 - 501ms/epoch - 5ms/step
# Epoch 47/100
# 96/96 - 0s - loss: 5554.2109 - 466ms/epoch - 5ms/step
# Epoch 48/100
# 96/96 - 0s - loss: 5523.4712 - 497ms/epoch - 5ms/step
# Epoch 49/100
# 96/96 - 0s - loss: 5518.3003 - 466ms/epoch - 5ms/step
# Epoch 50/100
# 96/96 - 0s - loss: 5478.7988 - 477ms/epoch - 5ms/step
# Epoch 51/100
# 96/96 - 1s - loss: 5495.7202 - 656ms/epoch - 7ms/step
# Epoch 52/100
# 96/96 - 1s - loss: 5460.2197 - 652ms/epoch - 7ms/step
# Epoch 53/100
# 96/96 - 1s - loss: 5450.8257 - 644ms/epoch - 7ms/step
# Epoch 54/100
# 96/96 - 1s - loss: 5446.5474 - 663ms/epoch - 7ms/step
# Epoch 55/100
# 96/96 - 1s - loss: 5456.9614 - 673ms/epoch - 7ms/step
# Epoch 56/100
# 96/96 - 1s - loss: 5422.6953 - 609ms/epoch - 6ms/step
# Epoch 57/100
# 96/96 - 0s - loss: 5392.2368 - 492ms/epoch - 5ms/step
# Epoch 58/100
# 96/96 - 0s - loss: 5377.2007 - 477ms/epoch - 5ms/step
# Epoch 59/100
# 96/96 - 0s - loss: 5378.3188 - 497ms/epoch - 5ms/step
# Epoch 60/100
# 96/96 - 0s - loss: 5424.3208 - 476ms/epoch - 5ms/step
# Epoch 61/100
# 96/96 - 0s - loss: 5365.0171 - 475ms/epoch - 5ms/step
# Epoch 62/100
# 96/96 - 0s - loss: 5391.7109 - 477ms/epoch - 5ms/step
# Epoch 63/100
# 96/96 - 0s - loss: 5358.5557 - 491ms/epoch - 5ms/step
# Epoch 64/100
# 96/96 - 0s - loss: 5350.4780 - 476ms/epoch - 5ms/step
# Epoch 65/100
# 96/96 - 1s - loss: 5305.2656 - 526ms/epoch - 5ms/step
# Epoch 66/100
# 96/96 - 1s - loss: 5312.6846 - 502ms/epoch - 5ms/step
# Epoch 67/100
# 96/96 - 0s - loss: 5334.8164 - 480ms/epoch - 5ms/step
# Epoch 68/100
# 96/96 - 1s - loss: 5297.9795 - 504ms/epoch - 5ms/step
# Epoch 69/100
# 96/96 - 0s - loss: 5260.2026 - 480ms/epoch - 5ms/step
# Epoch 70/100
# 96/96 - 0s - loss: 5261.9922 - 460ms/epoch - 5ms/step
# Epoch 71/100
# 96/96 - 0s - loss: 5242.9448 - 477ms/epoch - 5ms/step
# Epoch 72/100
# 96/96 - 1s - loss: 5206.7808 - 508ms/epoch - 5ms/step
# Epoch 73/100
# 96/96 - 0s - loss: 5182.5986 - 481ms/epoch - 5ms/step
# Epoch 74/100
# 96/96 - 1s - loss: 5169.1172 - 518ms/epoch - 5ms/step
# Epoch 75/100
# 96/96 - 0s - loss: 5157.0361 - 472ms/epoch - 5ms/step
# Epoch 76/100
# 96/96 - 1s - loss: 5142.6812 - 550ms/epoch - 6ms/step
# Epoch 77/100
# 96/96 - 1s - loss: 5144.2896 - 702ms/epoch - 7ms/step
# Epoch 78/100
# 96/96 - 1s - loss: 5163.9570 - 672ms/epoch - 7ms/step
# Epoch 79/100
# 96/96 - 1s - loss: 5149.2612 - 658ms/epoch - 7ms/step
# Epoch 80/100
# 96/96 - 1s - loss: 5123.0171 - 677ms/epoch - 7ms/step
# Epoch 81/100
# 96/96 - 1s - loss: 5099.4731 - 671ms/epoch - 7ms/step
# Epoch 82/100
# 96/96 - 1s - loss: 5087.7769 - 578ms/epoch - 6ms/step
# Epoch 83/100
# 96/96 - 0s - loss: 5150.5786 - 465ms/epoch - 5ms/step
# Epoch 84/100
# 96/96 - 0s - loss: 5202.2549 - 493ms/epoch - 5ms/step
# Epoch 85/100
# 96/96 - 0s - loss: 5135.9141 - 464ms/epoch - 5ms/step
# Epoch 86/100
# 96/96 - 0s - loss: 5135.4453 - 484ms/epoch - 5ms/step
# Epoch 87/100
# 96/96 - 0s - loss: 5105.5352 - 481ms/epoch - 5ms/step
# Epoch 88/100
# 96/96 - 1s - loss: 5079.4805 - 503ms/epoch - 5ms/step
# Epoch 89/100
# 96/96 - 1s - loss: 5053.9131 - 505ms/epoch - 5ms/step
# Epoch 90/100
# 96/96 - 1s - loss: 5065.4277 - 506ms/epoch - 5ms/step
# Epoch 91/100
# 96/96 - 0s - loss: 5032.5522 - 474ms/epoch - 5ms/step
# Epoch 92/100
# 96/96 - 0s - loss: 5017.7495 - 476ms/epoch - 5ms/step
# Epoch 93/100
# 96/96 - 0s - loss: 5014.6143 - 473ms/epoch - 5ms/step
# Epoch 94/100
# 96/96 - 0s - loss: 5002.0215 - 476ms/epoch - 5ms/step
# Epoch 95/100
# 96/96 - 0s - loss: 5144.4712 - 480ms/epoch - 5ms/step
# Epoch 96/100
# 96/96 - 1s - loss: 5165.8218 - 514ms/epoch - 5ms/step
# Epoch 97/100
# 96/96 - 0s - loss: 5082.2930 - 466ms/epoch - 5ms/step
# Epoch 98/100
# 96/96 - 1s - loss: 5057.5942 - 506ms/epoch - 5ms/step
# Epoch 99/100
# 96/96 - 0s - loss: 5035.5479 - 473ms/epoch - 5ms/step
# Epoch 100/100
# 96/96 - 0s - loss: 5018.5991 - 488ms/epoch - 5ms/step
# 51/51 [==============================] - 0s 3ms/step
# [[140.85312  139.50359  137.71512  ... 110.75939  108.674736 108.80763 ]
#  [134.19553  133.63666  132.19003  ... 110.34456  108.61211  109.00005 ]
#  [130.28754  129.66129  128.0441   ... 106.94674  105.18822  105.55458 ]
#  ...
#  [ 68.40675   69.76504   70.78634  ...  85.30047   85.53677   86.23853 ]
#  [ 64.61547   65.80965   67.11816  ...  82.49758   83.07054   83.71496 ]
#  [ 69.85871   71.03439   72.123505 ...  85.174736  85.60602   86.33303 ]]
# [[129. 121. 111. ... 221. 179. 155.]
#  [121. 111. 121. ... 179. 155. 172.]
#  [111. 121. 123. ... 155. 172. 187.]
#  ...
#  [ 42.  44.  48. ... 110. 117. 117.]
#  [ 44.  48.  45. ... 117. 117. 119.]
#  [ 48.  45.  36. ... 117. 119. 109.]]
# Mean Squared Error (MSE) for step size 30: 4088.9722582303034
# Mean Absolute Error (MAE) for step size 30: 47.641893225145985
# Epoch 1/100
# 95/95 - 3s - loss: 14062.0029 - 3s/epoch - 35ms/step
# Epoch 2/100
# 95/95 - 1s - loss: 12450.5518 - 598ms/epoch - 6ms/step
# Epoch 3/100
# 95/95 - 1s - loss: 11365.4170 - 590ms/epoch - 6ms/step
# Epoch 4/100
# 95/95 - 1s - loss: 10532.8047 - 613ms/epoch - 6ms/step
# Epoch 5/100
# 95/95 - 1s - loss: 9868.3828 - 636ms/epoch - 7ms/step
# Epoch 6/100
# 95/95 - 1s - loss: 9334.9492 - 596ms/epoch - 6ms/step
# Epoch 7/100
# 95/95 - 1s - loss: 8907.5928 - 613ms/epoch - 6ms/step
# Epoch 8/100
# 95/95 - 1s - loss: 8566.9463 - 609ms/epoch - 6ms/step
# Epoch 9/100
# 95/95 - 1s - loss: 8297.1836 - 592ms/epoch - 6ms/step
# Epoch 10/100
# 95/95 - 1s - loss: 8085.2446 - 597ms/epoch - 6ms/step
# Epoch 11/100
# 95/95 - 1s - loss: 7918.8477 - 623ms/epoch - 7ms/step
# Epoch 12/100
# 95/95 - 1s - loss: 7791.1772 - 605ms/epoch - 6ms/step
# Epoch 13/100
# 95/95 - 1s - loss: 7735.4814 - 607ms/epoch - 6ms/step
# Epoch 14/100
# 95/95 - 1s - loss: 7635.0527 - 605ms/epoch - 6ms/step
# Epoch 15/100
# 95/95 - 1s - loss: 7607.4629 - 608ms/epoch - 6ms/step
# Epoch 16/100
# 95/95 - 1s - loss: 7564.1851 - 616ms/epoch - 6ms/step
# Epoch 17/100
# 95/95 - 1s - loss: 7525.1426 - 692ms/epoch - 7ms/step
# Epoch 18/100
# 95/95 - 1s - loss: 7434.1890 - 803ms/epoch - 8ms/step
# Epoch 19/100
# 95/95 - 1s - loss: 7473.8701 - 802ms/epoch - 8ms/step
# Epoch 20/100
# 95/95 - 1s - loss: 7414.0259 - 805ms/epoch - 8ms/step
# Epoch 21/100
# 95/95 - 1s - loss: 7352.2876 - 804ms/epoch - 8ms/step
# Epoch 22/100
# 95/95 - 1s - loss: 7300.9292 - 640ms/epoch - 7ms/step
# Epoch 23/100
# 95/95 - 1s - loss: 7296.1855 - 590ms/epoch - 6ms/step
# Epoch 24/100
# 95/95 - 1s - loss: 7258.8491 - 589ms/epoch - 6ms/step
# Epoch 25/100
# 95/95 - 1s - loss: 7194.2817 - 590ms/epoch - 6ms/step
# Epoch 26/100
# 95/95 - 1s - loss: 7152.6411 - 601ms/epoch - 6ms/step
# Epoch 27/100
# 95/95 - 1s - loss: 7122.0889 - 594ms/epoch - 6ms/step
# Epoch 28/100
# 95/95 - 1s - loss: 7164.8193 - 583ms/epoch - 6ms/step
# Epoch 29/100
# 95/95 - 1s - loss: 7160.3696 - 588ms/epoch - 6ms/step
# Epoch 30/100
# 95/95 - 1s - loss: 7095.9565 - 592ms/epoch - 6ms/step
# Epoch 31/100
# 95/95 - 1s - loss: 7134.1680 - 601ms/epoch - 6ms/step
# Epoch 32/100
# 95/95 - 1s - loss: 7064.4453 - 599ms/epoch - 6ms/step
# Epoch 33/100
# 95/95 - 1s - loss: 7028.6792 - 611ms/epoch - 6ms/step
# Epoch 34/100
# 95/95 - 1s - loss: 7058.7202 - 597ms/epoch - 6ms/step
# Epoch 35/100
# 95/95 - 1s - loss: 6988.7900 - 601ms/epoch - 6ms/step
# Epoch 36/100
# 95/95 - 1s - loss: 6960.0342 - 596ms/epoch - 6ms/step
# Epoch 37/100
# 95/95 - 1s - loss: 6931.1855 - 587ms/epoch - 6ms/step
# Epoch 38/100
# 95/95 - 1s - loss: 6924.7437 - 632ms/epoch - 7ms/step
# Epoch 39/100
# 95/95 - 1s - loss: 6908.8398 - 797ms/epoch - 8ms/step
# Epoch 40/100
# 95/95 - 1s - loss: 6880.6177 - 772ms/epoch - 8ms/step
# Epoch 41/100
# 95/95 - 1s - loss: 6857.0762 - 770ms/epoch - 8ms/step
# Epoch 42/100
# 95/95 - 1s - loss: 6899.3213 - 817ms/epoch - 9ms/step
# Epoch 43/100
# 95/95 - 1s - loss: 6886.2622 - 728ms/epoch - 8ms/step
# Epoch 44/100
# 95/95 - 1s - loss: 6891.4834 - 592ms/epoch - 6ms/step
# Epoch 45/100
# 95/95 - 1s - loss: 6882.8618 - 616ms/epoch - 6ms/step
# Epoch 46/100
# 95/95 - 1s - loss: 6891.5991 - 589ms/epoch - 6ms/step
# Epoch 47/100
# 95/95 - 1s - loss: 6841.7700 - 600ms/epoch - 6ms/step
# Epoch 48/100
# 95/95 - 1s - loss: 6848.4487 - 608ms/epoch - 6ms/step
# Epoch 49/100
# 95/95 - 1s - loss: 6815.4648 - 597ms/epoch - 6ms/step
# Epoch 50/100
# 95/95 - 1s - loss: 6780.0391 - 595ms/epoch - 6ms/step
# Epoch 51/100
# 95/95 - 1s - loss: 6757.3901 - 594ms/epoch - 6ms/step
# Epoch 52/100
# 95/95 - 1s - loss: 6723.3232 - 602ms/epoch - 6ms/step
# Epoch 53/100
# 95/95 - 1s - loss: 6697.5083 - 604ms/epoch - 6ms/step
# Epoch 54/100
# 95/95 - 1s - loss: 6786.4604 - 601ms/epoch - 6ms/step
# Epoch 55/100
# 95/95 - 1s - loss: 6699.8179 - 601ms/epoch - 6ms/step
# Epoch 56/100
# 95/95 - 1s - loss: 6690.9253 - 601ms/epoch - 6ms/step
# Epoch 57/100
# 95/95 - 1s - loss: 6648.1621 - 596ms/epoch - 6ms/step
# Epoch 58/100
# 95/95 - 1s - loss: 6636.3638 - 604ms/epoch - 6ms/step
# Epoch 59/100
# 95/95 - 1s - loss: 6610.1538 - 607ms/epoch - 6ms/step
# Epoch 60/100
# 95/95 - 1s - loss: 6646.9570 - 806ms/epoch - 8ms/step
# Epoch 61/100
# 95/95 - 1s - loss: 6595.0088 - 821ms/epoch - 9ms/step
# Epoch 62/100
# 95/95 - 1s - loss: 6631.9395 - 825ms/epoch - 9ms/step
# Epoch 63/100
# 95/95 - 1s - loss: 6587.1250 - 834ms/epoch - 9ms/step
# Epoch 64/100
# 95/95 - 1s - loss: 6562.8374 - 672ms/epoch - 7ms/step
# Epoch 65/100
# 95/95 - 1s - loss: 6540.9688 - 613ms/epoch - 6ms/step
# Epoch 66/100
# 95/95 - 1s - loss: 6610.1831 - 584ms/epoch - 6ms/step
# Epoch 67/100
# 95/95 - 1s - loss: 6535.6348 - 592ms/epoch - 6ms/step
# Epoch 68/100
# 95/95 - 1s - loss: 6532.6211 - 599ms/epoch - 6ms/step
# Epoch 69/100
# 95/95 - 1s - loss: 6549.4849 - 595ms/epoch - 6ms/step
# Epoch 70/100
# 95/95 - 1s - loss: 6518.1719 - 604ms/epoch - 6ms/step
# Epoch 71/100
# 95/95 - 1s - loss: 6504.7876 - 586ms/epoch - 6ms/step
# Epoch 72/100
# 95/95 - 1s - loss: 6528.4229 - 604ms/epoch - 6ms/step
# Epoch 73/100
# 95/95 - 1s - loss: 6483.6836 - 621ms/epoch - 7ms/step
# Epoch 74/100
# 95/95 - 1s - loss: 6470.4912 - 591ms/epoch - 6ms/step
# Epoch 75/100
# 95/95 - 1s - loss: 6435.4746 - 597ms/epoch - 6ms/step
# Epoch 76/100
# 95/95 - 1s - loss: 6437.1401 - 609ms/epoch - 6ms/step
# Epoch 77/100
# 95/95 - 1s - loss: 6399.6509 - 594ms/epoch - 6ms/step
# Epoch 78/100
# 95/95 - 1s - loss: 6376.9170 - 591ms/epoch - 6ms/step
# Epoch 79/100
# 95/95 - 1s - loss: 6358.0923 - 614ms/epoch - 6ms/step
# Epoch 80/100
# 95/95 - 1s - loss: 6404.7373 - 609ms/epoch - 6ms/step
# Epoch 81/100
# 95/95 - 1s - loss: 6352.2983 - 810ms/epoch - 9ms/step
# Epoch 82/100
# 95/95 - 1s - loss: 6346.7637 - 845ms/epoch - 9ms/step
# Epoch 83/100
# 95/95 - 1s - loss: 6336.0347 - 800ms/epoch - 8ms/step
# Epoch 84/100
# 95/95 - 1s - loss: 6318.2524 - 811ms/epoch - 9ms/step
# Epoch 85/100
# 95/95 - 1s - loss: 6303.7368 - 735ms/epoch - 8ms/step
# Epoch 86/100
# 95/95 - 1s - loss: 6298.0522 - 608ms/epoch - 6ms/step
# Epoch 87/100
# 95/95 - 1s - loss: 6328.6685 - 587ms/epoch - 6ms/step
# Epoch 88/100
# 95/95 - 1s - loss: 6385.5093 - 599ms/epoch - 6ms/step
# Epoch 89/100
# 95/95 - 1s - loss: 6330.8608 - 585ms/epoch - 6ms/step
# Epoch 90/100
# 95/95 - 1s - loss: 6283.6714 - 623ms/epoch - 7ms/step
# Epoch 91/100
# 95/95 - 1s - loss: 6300.9263 - 598ms/epoch - 6ms/step
# Epoch 92/100
# 95/95 - 1s - loss: 6291.8071 - 601ms/epoch - 6ms/step
# Epoch 93/100
# 95/95 - 1s - loss: 6262.1777 - 601ms/epoch - 6ms/step
# Epoch 94/100
# 95/95 - 1s - loss: 6172.1230 - 592ms/epoch - 6ms/step
# Epoch 95/100
# 95/95 - 1s - loss: 6165.9492 - 593ms/epoch - 6ms/step
# Epoch 96/100
# 95/95 - 1s - loss: 6147.1948 - 616ms/epoch - 6ms/step
# Epoch 97/100
# 95/95 - 1s - loss: 6152.3516 - 585ms/epoch - 6ms/step
# Epoch 98/100
# 95/95 - 1s - loss: 6152.6484 - 606ms/epoch - 6ms/step
# Epoch 99/100
# 95/95 - 1s - loss: 6098.4810 - 603ms/epoch - 6ms/step
# Epoch 100/100
# 95/95 - 1s - loss: 6016.1748 - 597ms/epoch - 6ms/step
# 49/49 [==============================] - 0s 4ms/step
# [[ 54.837845  56.233     56.940773 ...  86.4228    87.08614   87.14432 ]
#  [ 49.02622   50.48128   51.297115 ...  83.98429   84.574524  84.794525]
#  [ 65.05317   66.21741   66.7219   ...  90.35558   91.00048   90.81691 ]
#  ...
#  [125.82901  125.8002   123.71948  ...  90.529495  90.805885  90.34605 ]
#  [124.331635 124.41469  122.27541  ...  88.94565   89.295395  88.81299 ]
#  [128.61292  128.52884  126.16494  ...  87.92373   88.237144  87.59932 ]]
# [[ 27.  45.  50. ... 136. 126. 115.]
#  [ 45.  50.  85. ... 126. 115. 107.]
#  [ 50.  85. 102. ... 115. 107. 114.]
#  ...
#  [107. 118. 123. ... 110. 117. 117.]
#  [118. 123. 118. ... 117. 117. 119.]
#  [123. 118. 119. ... 117. 119. 109.]]
# Mean Squared Error (MSE) for step size 60: 4812.72145163388
# Mean Absolute Error (MAE) for step size 60: 54.814594454608326
